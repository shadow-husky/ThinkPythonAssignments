# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week8/Palindrome_Tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# Convert the word to lowercase so capitalization does not matter
def is_palindrome(word):
# Reverse the word using slicing
  word = word.lower()
# Compare the original lowercase word to the reversed word
  if word == word[::-1]:

# If they are the same, return True
    return True
# Otherwise, return False
  else:
    return False



# PROGRAM LOGIC
# Ask the user to enter a word
user_word = input("Enter a word: ")
# Call the is_palindrome function with the user input
result = is_palindrome(user_word)
# Store the returned result
# If the result is True:
if result:
    print(user_word, "is a palindrome!")
# Print a message saying the word is a palindrome
# Print a message saying the word is not a palindrome
else:
    print(user_word, "is NOT a palindrome.")
