# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week10/Roster_Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS
# (NONE)

# FUNCTION DEFINITIONS
# ADD_PLAYERS(LIST)
def add_player(roster):
# - loop forever (while true)
  while True:
# - ask user for a player name
    name = input("Enter player name (or 'quit' to stop): ")
# - if user types "quit", break the loop
    if name.lower() == "quit":
      break
# - otherwise append name to list
    roster.append(name)

#is_on_roster(list, name)
# - loop through each player in list
# - if player matches name, return true

# PROGRAM LOGIC
# - create empty list called roster
roster = []
# - call add_players(roster)
add_players(roster)
# - ask user for a name to search
# - call is_on_roster(roster, name)
# - print result based on True/False
print("Current roster:", roster)
# Out:
# Enter player name (or 'quit' to stop): Josh
# Enter player name (or 'quit' to stop): quit
# Current roster: ['Josh']
