# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week3/Bio_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIC
# Assign values to name, goal, birth year, and current year
name = "Josh Perry"
goal = "Software developer or Cyber Security"
birth_year = 1996
current_year = 2026
# Calculate age
age = current_year - birth_year
# Print top border
print("-" * 104)
# Print Bio
print("My name is " + name + " and I am " + str(age) + " years old. My goal is to become a" + goal + ".")
# Print Bottom border
print("-" * 104)
# Out:
# --------------------------------------------------------------------------------------------------------
# My name is Josh Perry and I am 30 years old. My goal is to become aSoftware developer or Cyber Security.
# --------------------------------------------------------------------------------------------------------
