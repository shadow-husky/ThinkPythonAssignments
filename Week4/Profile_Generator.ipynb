# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week4/Profile_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
# 2. Inside the function, use string multiplication (*) for a border line.
  print("*" * 25)
# 3. Print the bio details using the parameter names.
  print("Name:", name, "Age:", age, "Goal:", goal)
  print("*" * 25)

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Josh", 29, "To work in Cybersecurity")
# 2. Call print_bio using Steve Jobs.
print_bio("Steve Jobs", 51, "Invented Iphone")
# 3. Call print_bio using Sherlock Holmes.
print_bio("Bill Gates", 19, "Co-Founded Microsoft")
# Out:
# *************************
# Name: Josh Age: 29 Goal: To work in Cybersecurity
# *************************
# *************************
# Name: Steve Jobs Age: 51 Goal: Invented Iphone
# *************************
# *************************
# Name: Bill Gates Age: 19 Goal: Co-Founded Microsoft
# *************************
