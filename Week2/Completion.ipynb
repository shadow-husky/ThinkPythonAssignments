# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week2/Completion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Total minutes in movie:", 2 * 60 + 45)
print("Years since first bug:", 2026 - 1947)
print("Total cost of books:", 7 * 35)
# Out:
# Total minutes in movie: 165
# Years since first bug: 79
# Total cost of books: 245
