# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week7/ATM_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
def verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True
  while True:
    entered_pin = input("Enter your PIN: ")

    if entered_pin == "1234":
          print("PIN Verified")
          return True
    else:
          print("Incorrect PIN. Try again.")
# 2. Define withdraw(balance, amount):
def withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance
  if amount <= balance:
    balance = balance - amount
    print("Withdrawal successful.")
    return balance
  else:
    print("Insufficient funds.")
    return balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500
# 2. Call verify_pin()
verify_pin()
# 3. Get withdrawal amount from user input
amount = float(input("Enter withdrawal amount: "))
# 4. Update current_balance by calling withdraw()
current_balance = withdraw(current_balance, amount)
# 5. Print the final balance
print("Current Balance: $" + str(current_balance))
# Out:
# Enter your PIN: 0000
# Incorrect PIN. Try again.
# Enter your PIN: 15677
# Incorrect PIN. Try again.
# Enter your PIN: 1234
# PIN Verified
# Enter withdrawal amount: 500
# Withdrawal successful.
# Current Balance: $0.0
