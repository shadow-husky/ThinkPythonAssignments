# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week14_16/library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS
# init self, title, and author
# Store Title
# Store Author
# is_available needs to be true

# str (self)
# if the book is available show "Available"
# if not show "Checked Out"
# return string "Title by Author - Status"

# Checkout
# is_available set to False

# return book
# is_available set to True

# PROGRAM LOGIC
# create two book objects
# print both books
# checkout one book
# print both books again showing change
