# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week13/Journal_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# write_entry(filename, entry)
def write_entry(filename, entry):
# Open file in append mode ('a')
    f = open(filename, 'a')
# Write entry + newline (\n) so each entry is on its own line
    f.write(entry + "\n")
# close file
    f.close()
    print("Entry Saved.")

# read_journal(filename)
def read_journal(filename):
    try:

# Open file in read mode ('r')
        with open(filename, 'r') as f:
# Read entire contents
            print("\n--- Your Journal ---")
            print(f.read())
# close file
            f.close()
# FileNotFoundError print message saying no journal exists
    except FileNotFoundError:
        print("\nNo journal exists yet.")

# PROGRAM LOGIC

# set filename = "journal.txt"
filename = "journal.txt"

# Loop forever
while True:
# ask user for write, read, or quit
  choice = input("Do you want to (W)rite, (R)ead, or (Q)uit? ").lower()
# IF W ask for entry
  if choice == 'w':
      entry = input("Enter your journal entry: ")
# Call write_entry
      write_entry(filename, entry)
# IF R call read_journal
  elif choice == 'r':
      read_journal(filename)
# IF Q Loop end
  elif choice == 'q':
      print("Goodbye")
      break
# Print invalid input
  else:
      print("Invalid input. Please try again.")
# Out:
# Do you want to (W)rite, (R)ead, or (Q)uit? w
# Enter your journal entry: Hello World!
# Entry Saved.
# Do you want to (W)rite, (R)ead, or (Q)uit? r
#
# --- Your Journal ---
# I made a program in python today.
# Hello World!
#
# Do you want to (W)rite, (R)ead, or (Q)uit? q
# Goodbye
