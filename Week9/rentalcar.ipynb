# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week9/rentalcar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rentalcar.py
#IMPORT STATEMENTS

#FUNCTION DEFINITIONS

# Get the daily rate
# code B should be 40
# code S should be 60
# code L should be 80

def daily_rate(code):
  if code == "B":
    return 40
  elif code == "S":
    return 60
  elif code == "L":
    return 80

# get the classification
# if the code is B, that is for Budget
# if the code is S, that is for Standard
# if the code is L, that is for Luxury

def get_class_name(code):
  if code == "B":
    return "Budget"
  elif code == "S":
    return "Standard"
  elif code == "L":
    return "Luxury"


# calculate the mileage
# if the total miles is greater than 100
# return the total miles minus the 100
# if not then return as 0

def calculate_mileage(total_miles):
  if total_miles > 100:
    return total_miles - 100
  else:
    return 0

# calculate the total bill
# get the daily rental rate
# get the charged mileage
# multiply the daily rate by the number of days
# multiply the charged mileage by 0.35
# add both values together
# return the total cost/bill

def calculate_bill_total(code, days, total_miles):
  pass

# PROGRAM LOGIC

# ask the user for class code
# check and make sure the code is either B, S, or L
# ask again is the class is wrong

classification = input("Enter Class of vehicle (B, S, L): ")

while classification != "B" and classification != "S" and classification != "L":
  print("Invalid vehicle class")
  classification = input("Enter Class of vehicle (B, S, L): ")

# ask for the beginning of the odometer
# ask for the end
# ask for days it is rented

beginning_odometer = int(input("Beginning Odometer: "))
end_odometer = int(input("End Odometer: "))
days_rented = int(input("Days Rented: "))

# calculate the total miles

total_miles = end_odometer - beginning_odometer

# call the function to calculate the mileage
# call the function to calculate the bill
# call the function to get the class name

charged_miles = calculate_mileage(total_miles)
class_name = get_class_name(classification)

# print the rental summary
# print the class name
# print the miles
# print charged miles
# print the total

print("Rental Summary")
print("Classification:", class_name)
print("Total Miles:", total_miles)
print("Charged Miles:", charged_miles)
# Out:
# Enter Class of vehicle (B, S, L): L
# Beginning Odometer: 50
# End Odometer: 250
# Days Rented: 3
# Rental Summary
# Classification: Luxury
# Total Miles: 200
# Charged Miles: 100
