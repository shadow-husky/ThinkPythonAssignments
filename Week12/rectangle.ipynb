# %% [markdown]
# <a href="https://colab.research.google.com/github/shadow-husky/ThinkPythonAssignments/blob/main/Week12/rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py

# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# calculate rectangle length and width
# calculate the area using legnth * width
# Put both values into tuple (area and perimeter)
# return the tuple

# PROGRAM LOGIC
# ask user for length
# ask user for width
# call the function and store the results
# unpack tuple into two variables
# my_area, my_perimeter = result

# print results
# print area
# print perimeter
